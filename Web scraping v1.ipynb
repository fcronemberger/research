# %%
from lxml import html
import requests
import pandas as pd
import numpy as np


########OPEN DATA PORTAL

df = pd.read_json("https://data.smcgov.org/resource/mb6a-xn89.json")
df.head(5)




page = requests.get('http://econpy.pythonanywhere.com/ex/004.html')
tree = html.fromstring(page.content)

#This will create a list of buyers:
buyers = tree.xpath('//div[@title="buyer-name"]/text()')
#This will create a list of prices
prices = tree.xpath('//span[@class="item-price"]/text()')

#Turning it into a data frame

buyersdf = pd.DataFrame(buyers) 
pricesdf = pd.DataFrame(prices) 


#Converting to numeric types

pricesdfb = pd.Series(result['b'])
pricesdfc = pd.Series(result['c'])

pricesdfb = pd.to_numeric(pricesdfb, errors='ignore')
pricesdfc = pd.to_numeric(pricesdfc, errors='ignore')



#buyersdf.head()
#pricesdf.head()


#Concatenate data

result = pd.concat([buyersdf, pricesdfb, pricesdfc], axis=1)

#Renaming Columns

#result.columns = ['', 'b']
#result.head()

#########Creates a copy of the column

result['c'] = result['b'] #New column = old column

x = result.loc[0,'c'] 


#########Creates a copy of the column

result['d'] = result['c'] #New column = old column

x = result.loc[0,'c'] 

####Remove values($) from the column

#result.b = [x.strip('$') for x in                           
#result.b]

###Replacing values

#result = result.apply(lambda x: x.str.replace('.',','))

#Sum of two columns in a third column


result['d'] = result['b'] + result['c'] 
result['e'] = result['b'] + result['c'] + result['d'] 


#Renaming Columns

#result.rename(columns={"0": "ID", "b": "Timestamp", "c": "Geolocation", "d":"Blabla", "e": "dasdasdas"})
result.columns = ['Names', 'X', 'Y', 'W', 'Z']

###Droping / Deleting columns

#result.drop('b', axis=1)

#result['e'] = result['b'] * 2
#result['f'] = result['b'] * 3

######Convert to Numeric types
 
result
# Out:
#                Names      X      Y      W       Z
# 0       Gill D. Lily  21.21  21.21  42.42   84.84
# 1         Cole Mines  11.56  11.56  23.12   46.24
# 2      Phil R. Monik   8.99   8.99  17.98   35.96
# 3        L.O. Quency  14.30  14.30  28.60   57.20
# 4        Connel Radd   4.99   4.99   9.98   19.96
# 5       Ben D. Rules  45.00  45.00  90.00  180.00
# 6       Cleon Sheets  16.27  16.27  32.54   65.08
# 7     Renata Tampaks  14.24  14.24  28.48   56.96
# 8       Justin Thyme  10.98  10.98  21.96   43.92
# 9         Matt Tress  18.47  18.47  36.94   73.88
# 10         Vic Trola  11.43  11.43  22.86   45.72
# 11         Al Truist  17.63  17.63  35.26   70.52
# 12       Aaron Tyres  25.00  25.00  50.00  100.00
# 13    U.N. Wattarmey  16.13  16.13  32.26   64.52
# 14  Abe L.N. Willing   4.99   4.99   9.98   19.96
# 15      Jerry Atrick  14.11  14.11  28.22   56.44
# 16           Hy Ball  16.61  16.61  33.22   66.44
# 17      Jill E. Bean   9.49   9.49  18.98   37.96
# ...

# %%
#####EXPORT TO EXCEL################################################################

import tkinter as tk
from tkinter import filedialog

#Consolidating the data_frame

cars = {'Brand': ['Honda Civic','Toyota Corolla','Ford Focus','Audi A4'],
        'Price': [32000,35000,37000,45000]
        }

df = result


root= tk.Tk()

canvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue2', relief = 'raised')
canvas1.pack()

def exportExcel ():
    global df
    
    export_file_path = filedialog.asksaveasfilename(defaultextension='.xlsx')
    df.to_excel (export_file_path, index = False, header=True)

saveAsButtonExcel = tk.Button(text='Export Excel', command=exportExcel, bg='green', fg='white', font=('helvetica', 12, 'bold'))
canvas1.create_window(150, 150, window=saveAsButtonExcel)

root.mainloop()

print(df)
df.head()


result
# Out:
#                Names      X      Y      W       Z
# 0       Gill D. Lily  21.21  21.21  42.42   84.84
# 1         Cole Mines  11.56  11.56  23.12   46.24
# 2      Phil R. Monik   8.99   8.99  17.98   35.96
# 3        L.O. Quency  14.30  14.30  28.60   57.20
# 4        Connel Radd   4.99   4.99   9.98   19.96
# 5       Ben D. Rules  45.00  45.00  90.00  180.00
# 6       Cleon Sheets  16.27  16.27  32.54   65.08
# 7     Renata Tampaks  14.24  14.24  28.48   56.96
# 8       Justin Thyme  10.98  10.98  21.96   43.92
# 9         Matt Tress  18.47  18.47  36.94   73.88
# 10         Vic Trola  11.43  11.43  22.86   45.72
# 11         Al Truist  17.63  17.63  35.26   70.52
# 12       Aaron Tyres  25.00  25.00  50.00  100.00
# 13    U.N. Wattarmey  16.13  16.13  32.26   64.52
# 14  Abe L.N. Willing   4.99   4.99   9.98   19.96
# 15      Jerry Atrick  14.11  14.11  28.22   56.44
# 16           Hy Ball  16.61  16.61  33.22   66.44
# 17      Jill E. Bean   9.49   9.49  18.98   37.96
# ...

# %%
#############  OPEN DATA ANALYSIS ##############

# Reading it from the API

df = pd.read_json("https://data.smcgov.org/resource/mb6a-xn89.json")
df.head(5)

# Snapshot
df.shape
(32, 8)

df.describe()

df.dtypes


##### Snapshot for non-numeric characters

#df.drop("geolocation", axis=1).describe(include="all")

##### Counting Numbers

def mapGeography(x):
    if x == "City":
        return 1
    else:
        return 0

df['geography_mapped_value'] = df.geography_type.apply(mapGeography)

df.geography_mapped_value.value_counts()


df
# Out:
#                  geography geography_type                     year  \
# 0                 Atherton           Town  2014-01-01T00:00:00.000
# 1                    Colma           Town  2014-01-01T00:00:00.000
# 2              Foster City           City  2014-01-01T00:00:00.000
# 3           Portola Valley           Town  2014-01-01T00:00:00.000
# 4             Redwood City           City  2014-01-01T00:00:00.000
# 5                   Ladera            CDP  2014-01-01T00:00:00.000
# 6               Moss Beach            CDP  2014-01-01T00:00:00.000
# 7      South San Francisco           City  2014-01-01T00:00:00.000
# 8                  Belmont           City  2014-01-01T00:00:00.000
# 9                Daly City           City  2014-01-01T00:00:00.000
# 10               San Mateo           City  2014-01-01T00:00:00.000
# 11         North Fair Oaks            CDP  2014-01-01T00:00:00.000
# 12      Emerald Lake Hills            CDP  2014-01-01T00:00:00.000
# ...
